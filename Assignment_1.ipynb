# %% [markdown]
# <a href="https://colab.research.google.com/github/katehegland/Projects/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas #install the pandas library if it has never been run on colab before
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import json #allows your code to interpret the json language used commonly in APIs
import requests #allows your code to make http requests
import pandas as pd #a python library that can perform various requests. We used it to create a recipes df.
import random #allows you to request a random output

# %%
#processing the recipe data
def make_api_call(url, params=None, headers=None): #defining a function that returns a json response if the API call is successful
    """
    Make a GET request to the specified API endpoint.
    :param url: The API endpoint URL
    :param params: (optional) Dictionary of query parameters
    :param headers: (optional) Dictionary of HTTP headers
    :return: JSON response if successful, None otherwise
    """ #further explanation
    try:
        # Make the GET request
        response = requests.get(url, params=params, headers=headers) #use the requests library to pull data from the API and assign it to the variable response
        # Check if the request was successful
        response.raise_for_status() #raises an HTTP error if the response status code is a failure (ex. 404 Not Found or 500 Internal Server Error)

        data = response.json() #assigns the variable data to the response and converts it from json with .json()

        # Parse and return the JSON response
        recipes = [] #creates an empty list called recipes
        if not data['hits']: #if not checks if there are no hits in the data
          print("No recipes found") #a text output if there are no hits
          return 0 #a numerical output if there are no hits
        for hit in data['hits']: #a for loop that fills the recipes list with hits that extract a url, label, ingredients, and image from the data
          recipe = hit['recipe'] #a variable for the recipes extracted from the data
          recipes.append({'url': recipe['url'],'label': recipe['label'],'ingredients':recipe['ingredients'],'image': recipe['image']}) #appends the list recipes and clarifies the different items resulting from each hit that will be relabeled in the list
        df = pd.DataFrame(recipes) #creates a dataframe from the list recipes
        display(df) #displays the dataframe
        return data #returns the data if the API call is successful
    except requests.exceptions.RequestException as e: #if an exception occurs while processing the data
        print(f"An error occurred: {e}") #a text response that prints the error type
        return None #an additional response to indicate an error

# %%
#processing the fruit data
def get_fruit(url, params=None, headers=None): #Defining a function that returns a json response if the API call is successful
    try:
        # Make the GET request
        response = requests.get(url, params=params, headers=headers) #use the requests library to pull data from the API and assign it to the variable response

        # Check if the request was successful
        response.raise_for_status() #raises an HTTP error if the response status code is a failure (ex. 404 Not Found or 500 Internal Server Error)

        i = random.randint(0,50) #a variable assigned to a random integer from 0 to 50
        result = response.json()[i] #assigns a variable to the converted json response from the api and selects a fruit from the response with the random integer
        print(f"The fruit selected was: {result['name']}") #a text output that incorporates the fruit output
        return result['name'] #returns the fruit name
    except requests.exceptions.RequestException as e: #if an exception occurs while processing the data
        print(f"An error occurred: {e}") #a text response that prints the error
        return None #an additional response to indicate an error

# %%
#creating the feature
api_url = "https://api.edamam.com/api/recipes/v2" #assigning a variable to the recipe api
fruit_url = "https://www.fruityvice.com/api/fruit/all" #assigning a variable to the fruit api
fruit = get_fruit(fruit_url) #assigning a variable to the get_fruit function and inserts the fruit_url as the input
params = {"type": "public", "app_id": "757c083c","app_key":"2d327a070018d370d2ff3eb8c5732da0","q":fruit} #a dictionary of query parameters for the recipe API. It clarifies that you want to use the public recipe API, provides the app_id and app_key to access the API, then it assigns the query with the random fruit

result = make_api_call(api_url, params=params) #assigning a variable to the make_api_call function for a recipe with the api url as an input and the params dictionary
if result:
    print("API call successful!") #a text output if the API call is successful
else:
    print("Exiting program.") #a text output if the API call is not successful
    exit() #exits the program if the API call is not successful
# Out:
# The fruit selected was: Kiwifruit
#                                                   url  \
# 0   https://www.marthastewart.com/1513828/honey-fl...
# 1   http://www.eatingwell.com/recipe/267440/grapef...
# 2   https://www.epicurious.com/recipes/food/views/...
# 3   https://www.menshealth.com/recipes/crepes-with...
# 4   http://www.thedailymeal.com/recipes/korean-let...
# 5   https://www.williams-sonoma.com/recipe/kiwifru...
# 6   https://www.pbs.org/food/recipes/korean-style-...
# 7   https://www.myrecipes.com/recipe/strawberry-ki...
# 8   http://www.delish.com/cooking/recipe-ideas/rec...
# 9   https://www.marthastewart.com/360164/kiwi-summ...
# 10  https://www.eatingwell.com/recipe/258087/rainb...
# 11  https://www.myrecipes.com/recipe/kiwi-orange-a...
# 12  http://www.thedailymeal.com/recipes/kiwi-ginge...
# 13  https://www.menshealth.com/recipes/caramel-fla...
# 14  http://www.eatingwell.com/recipe/264112/choose...
# 15  http://www.thedailymeal.com/recipes/arugula-sa...
# 16  http://www.eatingwell.com/recipe/267170/strawb...
# 17  https://www.eatingwell.com/recipe/269536/honey...
# 18  https://www.eatingwell.com/recipe/266384/rainb...
# 19  http://www.eatingwell.com/recipe/265222/creamy...
#
#                                                 label  \
# 0                Honey Flan with Citrus and Kiwifruit
# 1                      Grapefruit and Kiwifruit Salad
# 2                                         Kiwi Sorbet
# 3                    Crepes with Banana and Kiwifruit
# 4   Korean Lettuce Cups with SunGold Kiwifruit and...
# 5   Kiwifruit, Apple & Grape Salad with Rosemary S...
# 6                           Korean-Style Grilled Beef
# 7                               Strawberry-Kiwi Juice
# 8            Spiced Pork Tenderloins with Mango Salsa
# 9                                    Kiwi Summer Roll
# 10                               Rainbow Fruit Kebabs
# 11                    Kiwi, Orange and Apple Smoothie
# 12                        Kiwi-Ginger Ice Cream Float
# 13                      Caramel Flan with Fresh Fruit
# 14                    Choose-a-Fruit Tropical Sherbet
# 15  Arugula Salad with Kiwi, Avocado, Soft-Boiled ...
# 16                   Strawberry-Kiwi Cheesecake Toast
# 17                         Honey-Balsamic Fruit Salad
# 18                              Rainbow Fruit Skewers
# 19                               Creamy Fruit Morsels
#
#                                           ingredients  \
# 0   [{'text': '1/2 cup honey, preferably raw and u...
# 1   [{'text': '1 tablespoon grapefruit juice', 'qu...
# 2   [{'text': '2 pounds tender ripe green kiwifrui...
# 3   [{'text': '1 cup whole grain pastry flour', 'q...
# 4   [{'text': '1 Cup gochujang sauce', 'quantity':...
# 5   [{'text': '1/4 cup sugar', 'quantity': 0.25, '...
# 6   [{'text': '1/3 cup soy sauce', 'quantity': 0.3...
# 7   [{'text': '4 cups strawberry halves', 'quantit...
# 8   [{'text': '2 medium ripe mangos', 'quantity': ...
# 9   [{'text': '1 1/2 ounces thin rice noodles', 'q...
# 10  [{'text': '4 strawberries', 'quantity': 4.0, '...
# 11  [{'text': '8 kiwifruit', 'quantity': 8.0, 'mea...
# 12  [{'text': '1 SunGold kiwifruit, sliced', 'quan...
# 13  [{'text': '2/3 cup sugar', 'quantity': 0.66666...
# 14  [{'text': '1 cup granulated sugar', 'quantity'...
# 15  [{'text': '1 SunGold Kiwifruit, peeled', 'quan...
# 16  [{'text': '2 tablespoons nonfat strawberry Gre...
# 17  [{'text': '1 pink or red grapefruit, peeled, s...
# 18  [{'text': '1 strawberry', 'quantity': 1.0, 'me...
# 19  [{'text': '½ (8 ounce) package fat-free cream ...
#
#                                                 image
# 0   https://edamam-product-images.s3.amazonaws.com...
# 1   https://edamam-product-images.s3.amazonaws.com...
# 2   https://edamam-product-images.s3.amazonaws.com...
# 3   https://edamam-product-images.s3.amazonaws.com...
# 4   https://edamam-product-images.s3.amazonaws.com...
# 5   https://edamam-product-images.s3.amazonaws.com...
# 6   https://edamam-product-images.s3.amazonaws.com...
# 7   https://edamam-product-images.s3.amazonaws.com...
# 8   https://edamam-product-images.s3.amazonaws.com...
# 9   https://edamam-product-images.s3.amazonaws.com...
# 10  https://edamam-product-images.s3.amazonaws.com...
# 11  https://edamam-product-images.s3.amazonaws.com...
# 12  https://edamam-product-images.s3.amazonaws.com...
# 13  https://edamam-product-images.s3.amazonaws.com...
# 14  https://edamam-product-images.s3.amazonaws.com...
# 15  https://edamam-product-images.s3.amazonaws.com...
# 16  https://edamam-product-images.s3.amazonaws.com...
# 17  https://edamam-product-images.s3.amazonaws.com...
# 18  https://edamam-product-images.s3.amazonaws.com...
# 19  https://edamam-product-images.s3.amazonaws.com...
# API call successful!
